# %% [markdown]
# # Meu primeiro código em Python com texto.

# %%
print("Primeiro código em Python")
# Out:
# Primeiro código em Python

# %% [markdown]
# # Primeiro código com números.

# %%
print(1393)
# Out:
# 1393
